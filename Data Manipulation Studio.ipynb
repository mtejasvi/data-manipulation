# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit our California farmers looking for advice on growing pumpkins and the same [pumpkins dataset](https://www.kaggle.com/usda/a-year-of-pumpkin-prices) as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the `dataset` folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

# %%
df_b=pd.read_csv('dataset/baltimore_9-24-2016_9-30-2017.csv')
df_b.shape
# Out:
# (153, 25)

# %%
df_bo=pd.read_csv('dataset/boston_9-24-2016_9-30-2017.csv')

df_bo.head(10)
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 5       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 6       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 7       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 8       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
# 9       PUMPKINS    BOSTON   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...   Color  Environment  \
# 0    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 1    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 2    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 3    NaN  09/24/2016        160         200  ...  ORANGE          NaN
# 4    NaN  09/24/2016        160         180  ...  ORANGE          NaN
# 5    NaN  09/24/2016        160         180  ...  ORANGE          NaN
# 6    NaN  09/24/2016        140         160  ...  ORANGE          NaN
# 7    NaN  09/24/2016        140         160  ...  ORANGE          NaN
# 8    NaN  09/24/2016        140         160  ...  ORANGE          NaN
# 9    NaN  09/24/2016        200         225  ...  ORANGE          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 5          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 6          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 7          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 8          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 9          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [10 rows x 25 columns]

# %%
df_n= pd.read_csv('dataset/new-york_9-24-2016_9-30-2017.csv')

df_n.head(10)
# Out:
#   Commodity Name City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 5       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 6       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 7       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 8       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
# 9       PUMPKINS  NEW YORK   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/24/2016        150         170  ...    NaN          NaN
# 1    NaN  09/24/2016        150         170  ...    NaN          NaN
# 2    NaN  09/24/2016        130         150  ...    NaN          NaN
# 3    NaN  09/24/2016        130         150  ...    NaN          NaN
# 4    NaN  09/24/2016        120         140  ...    NaN          NaN
# 5    NaN  09/24/2016        150         170  ...    NaN          NaN
# 6    NaN  09/24/2016        120         170  ...    NaN          NaN
# 7    NaN  09/24/2016        180         190  ...    NaN          NaN
# 8    NaN  10/01/2016        150         170  ...    NaN          NaN
# 9    NaN  10/01/2016        150         170  ...    NaN          NaN
#
#   Unit of Sale Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 1          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 2          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 5          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 6          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 7          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 8          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
# 9          NaN     NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [10 rows x 25 columns]

# %%
df_p=pd.read_csv('dataset/philadelphia_9-24-2016_9-30-2017.csv')

df_p.head(10)
# Out:
#   Commodity Name     City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  PHILADELPHIA   NaN  24 inch bins  HOWDEN TYPE         NaN
# 1       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 2       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 5       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 6       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 7       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 8       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
# 9       PUMPKINS  PHILADELPHIA   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  09/16/2017        140         150  ...    NaN          NaN
# 1    NaN  09/24/2016        150         150  ...    NaN          NaN
# 2    NaN  09/24/2016        150         150  ...    NaN          NaN
# 3    NaN  09/24/2016        150         160  ...    NaN          NaN
# 4    NaN  10/01/2016        140         140  ...    NaN          NaN
# 5    NaN  10/01/2016        140         140  ...    NaN          NaN
# 6    NaN  10/01/2016        120         120  ...    NaN          NaN
# 7    NaN  10/08/2016        140         155  ...    NaN          NaN
# 8    NaN  10/08/2016        120         120  ...    NaN          NaN
# 9    NaN  10/15/2016        120         125  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition  Appearance  Storage Crop  Repack  \
# 0          NaN      NaN       NaN         NaN      NaN  NaN       N
# 1          NaN      NaN       NaN         NaN      NaN  NaN       N
# 2          NaN      NaN       NaN         NaN      NaN  NaN       N
# 3          NaN      NaN       NaN         NaN      NaN  NaN       N
# 4          NaN      NaN       NaN         NaN      NaN  NaN       N
# 5          NaN      NaN       NaN         NaN      NaN  NaN       N
# 6          NaN      NaN       NaN         NaN      NaN  NaN       N
# 7          NaN      NaN       NaN         NaN      NaN  NaN       N
# 8          NaN      NaN       NaN         NaN      NaN  NaN       N
# 9          NaN      NaN       NaN         NaN      NaN  NaN       N
#
#    Trans Mode
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
#
# [10 rows x 25 columns]

# %% [markdown]
# ## Clean Your Data
#
# In the last lesson, we cleaned the data to related to San Francisco. Pull up your notebook from the last lesson and use your cleaning skills to clean the dataframes as necessary.

# %%
# Clean your data here!
df_numeric = df_b.select_dtypes(include=[np.number])
numeric_cols = df_numeric.columns.values
print('numeric values',numeric_cols)

# select non numeric columns
df_non_numeric = df_b.select_dtypes(exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print('non_numeric',non_numeric_cols)
# Out:
# numeric values ['Type' 'Grade' 'Low Price' 'High Price' 'Mostly Low' 'Mostly High'
#  'Origin District' 'Environment' 'Quality' 'Condition' 'Appearance'
#  'Storage' 'Crop' 'Trans Mode']
# non_numeric ['Commodity Name' 'City Name' 'Package' 'Variety' 'Sub Variety' 'Date'
#  'Origin' 'Item Size' 'Color' 'Unit of Sale' 'Repack']

# %%
cols = df_b.columns[:25] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df_b[cols].isnull(), cmap=sns.color_palette(colours))
print('baltimore',df_b.shape)
# Out:
# baltimore (153, 25)

# %%
cols = df_bo.columns[:25] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df_bo[cols].isnull(), cmap=sns.color_palette(colours))
print('boston',df_bo.shape)
# Out:
# boston (352, 25)

# %%
cols = df_n.columns[:25] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df_n[cols].isnull(), cmap=sns.color_palette(colours))
print('newyork',df_n.shape)
# Out:
# newyork (112, 25)

# %%
cols = df_p.columns[:25] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df_p[cols].isnull(), cmap=sns.color_palette(colours))
print('philadelphia',df_p.shape)
# Out:
# philadelphia (57, 25)

# %%
for col in df_b.columns:
    pct_missing = np.mean(df_b[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    print(df_b.shape)
# Out:
# Commodity Name - 0%
# (153, 25)
# City Name - 0%
# (153, 25)
# Type - 100%
# (153, 25)
# Package - 0%
# (153, 25)
# Variety - 1%
# (153, 25)
# Sub Variety - 84%
# (153, 25)
# Grade - 100%
# (153, 25)
# Date - 0%
# (153, 25)
# Low Price - 0%
# (153, 25)
# High Price - 0%
# (153, 25)
# Mostly Low - 0%
# (153, 25)
# Mostly High - 0%
# (153, 25)
# Origin - 3%
# (153, 25)
# Origin District - 100%
# (153, 25)
# Item Size - 16%
# (153, 25)
# Color - 80%
# (153, 25)
# Environment - 100%
# (153, 25)
# Unit of Sale - 84%
# (153, 25)
# Quality - 100%
# (153, 25)
# Condition - 100%
# (153, 25)
# Appearance - 100%
# (153, 25)
# Storage - 100%
# (153, 25)
# Crop - 100%
# (153, 25)
# Repack - 0%
# (153, 25)
# Trans Mode - 100%
# (153, 25)

# %%
df_b_dropcols=df_b.drop(columns=['Type','Crop','Storage','Appearance','Condition','Quality','Environment','Trans Mode','Grade','Origin District','Commodity Name','Mostly Low','Mostly High','Sub Variety','Color'],axis=1)

df_bo_dropcols=df_bo.drop(columns=['Type','Crop','Storage','Appearance','Condition','Quality','Environment','Trans Mode','Grade','Origin District','Commodity Name','Mostly Low','Mostly High','Sub Variety','Color'],axis=1)

df_n_dropcols=df_n.drop(columns=['Type','Crop','Storage','Appearance','Condition','Quality','Environment','Trans Mode','Grade','Origin District','Commodity Name','Mostly Low','Mostly High','Sub Variety','Color'],axis=1)

df_p_dropcols=df_p.drop(columns=['Type','Crop','Storage','Appearance','Condition','Quality','Environment','Trans Mode','Grade','Origin District','Commodity Name','Mostly Low','Mostly High','Sub Variety','Color'],axis=1)

# %%
df_b_dropcols['Date'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_bo_dropcols['Date'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_n_dropcols['Date'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_p_dropcols['Date'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df_p_dropcols.shape
# Out:
# (57, 10)

# %%
cols = df_b_dropcols.columns[:25] # first 30 columns
colours = ['#000099', '#ffff00'] # specify the colours - yellow is missing. blue is not missing.
sns.heatmap(df_b_dropcols[cols].isnull(), cmap=sns.color_palette(colours))
print('baltimore',df_b_dropcols.shape)
# Out:
# baltimore (153, 10)

# %%
df_b_dropcols.head(3)
# Out:
#    City Name       Package      Variety        Date  Low Price  High Price  \
# 0  BALTIMORE  24 inch bins          NaN  04/29/2017        270       280.0
# 1  BALTIMORE  24 inch bins          NaN  05/06/2017        270       280.0
# 2  BALTIMORE  24 inch bins  HOWDEN TYPE  09/24/2016        160       160.0
#
#      Origin Item Size Unit of Sale Repack
# 0       NaN       lge          NaN      E
# 1       NaN       lge          NaN      E
# 2  DELAWARE       med          NaN      N

# %%
df_b_dropcols.describe()
# Out:
#         Low Price  High Price
# count  153.000000  153.000000
# mean   101.490196  109.055556
# std     97.651981  101.969948
# min     15.000000   15.000000
# 25%     17.000000   18.000000
# 50%     50.000000   60.000000
# 75%    180.000000  180.000000
# max    380.000000  380.000000

# %%
df_bo_dropcols.describe()
# Out:
#         Low Price  High Price
# count  352.000000  352.000000
# mean   162.840909  187.235795
# std     77.513147   86.934652
# min     15.000000   16.000000
# 25%    140.000000  160.000000
# 50%    175.000000  200.000000
# 75%    200.000000  225.000000
# max    300.000000  300.000000

# %%
df_p_dropcols.describe()
# Out:
#         Low Price  High Price
# count   57.000000   57.000000
# mean    98.140351  103.754386
# std     62.020572   63.399606
# min     12.000000   12.000000
# 25%     18.000000   18.000000
# 50%    120.000000  125.000000
# 75%    140.000000  150.000000
# max    250.000000  250.000000

# %%
df_n_dropcols.describe()
# Out:
#         Low Price  High Price
# count  112.000000  112.000000
# mean   107.125000  116.482143
# std     71.840931   77.454664
# min     15.000000   16.000000
# 25%     18.000000   20.000000
# 50%    130.000000  140.000000
# 75%    150.000000  170.000000
# max    260.000000  300.000000

# %%
# Out:
# (112, 10)

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
df=pd.concat([df_b_dropcols,df_bo_dropcols,df_n_dropcols,df_p_dropcols])
df
# Out:
#        City Name             Package      Variety        Date  Low Price  \
# 0      BALTIMORE        24 inch bins          NaN  04/29/2017        270
# 1      BALTIMORE        24 inch bins          NaN  05/06/2017        270
# 2      BALTIMORE        24 inch bins  HOWDEN TYPE  09/24/2016        160
# 3      BALTIMORE        24 inch bins  HOWDEN TYPE  09/24/2016        160
# 4      BALTIMORE        24 inch bins  HOWDEN TYPE  11/05/2016         90
# ..           ...                 ...          ...         ...        ...
# 52  PHILADELPHIA  1/2 bushel cartons    MINIATURE  11/05/2016         16
# 53  PHILADELPHIA  1/2 bushel cartons    MINIATURE  08/26/2017         18
# 54  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/16/2017         16
# 55  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/23/2017         15
# 56  PHILADELPHIA  1/2 bushel cartons    MINIATURE  09/30/2017         15
#
#     High Price    Origin Item Size Unit of Sale Repack
# 0        280.0       NaN       lge          NaN      E
# 1        280.0       NaN       lge          NaN      E
# 2        160.0  DELAWARE       med          NaN      N
# 3        160.0  VIRGINIA       med          NaN      N
# 4        100.0  MARYLAND       lge          NaN      N
# ..         ...       ...       ...          ...    ...
# 52        18.0      OHIO       NaN   SHELLACKED      N
# 53        20.0  MICHIGAN       NaN   SHELLACKED      N
# 54        16.0      OHIO       NaN   SHELLACKED      N
# 55        16.0      OHIO       NaN   SHELLACKED      N
# 56        18.0      OHIO       NaN   SHELLACKED      N
#
# [674 rows x 10 columns]

# %%
df['Unit of Sale'].value_counts()
# Out:
# PER BIN       71
# EACH          24
# SHELLACKED    11
# Name: Unit of Sale, dtype: int64

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1. What is the mean low and high prices for each type of unit of sale in the Northeast region? In the last lesson, we learned that a unit of sale could be something like a bin or individually.
# 2. What is the average number of pumpkins for each variety that came into terminal markets for the year by region? Pumpkin varieties include Howden and Fairytale pumpkins.

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
df_unitofsale=df.groupby('Unit of Sale')

df_unitofsale['Low Price','High Price'].mean()
# Out:
# C:\Users\tejas\AppData\Local\Temp\ipykernel_31236\3387075007.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_unitofsale['Low Price','High Price'].mean()
#                Low Price  High Price
# Unit of Sale
# EACH           47.916667   59.166667
# PER BIN       185.845070  206.619718
# SHELLACKED     16.000000   17.545455

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
df_grpby=df['Vare']
# Out:
#         City Name       Package                   Variety        Date  \
# 2       BALTIMORE  24 inch bins               HOWDEN TYPE  09/24/2016
# 3       BALTIMORE  24 inch bins               HOWDEN TYPE  09/24/2016
# 4       BALTIMORE  24 inch bins               HOWDEN TYPE  11/05/2016
# 5       BALTIMORE  24 inch bins               HOWDEN TYPE  11/12/2016
# 6       BALTIMORE  36 inch bins               HOWDEN TYPE  09/24/2016
# ..            ...           ...                       ...         ...
# 293        BOSTON  24 inch bins              KNUCKLE HEAD  10/29/2016
# 294        BOSTON  24 inch bins              KNUCKLE HEAD  11/05/2016
# 81       NEW YORK  36 inch bins              KNUCKLE HEAD  10/08/2016
# 84       NEW YORK  24 inch bins  MIXED HEIRLOOM VARIETIES  10/08/2016
# 44   PHILADELPHIA  24 inch bins              KNUCKLE HEAD  10/08/2016
#
#      Low Price  High Price         Origin Item Size Unit of Sale Repack
# 2          160       160.0       DELAWARE       med          NaN      N
# 3          160       160.0       VIRGINIA       med          NaN      N
# 4           90       100.0       MARYLAND       lge          NaN      N
# 5           90       100.0       MARYLAND       lge          NaN      N
# 6          160       170.0       MARYLAND       med          NaN      N
# ..         ...         ...            ...       ...          ...    ...
# 293        260       285.0  MASSACHUSETTS      xlge          NaN      N
# 294        260       285.0  MASSACHUSETTS      xlge          NaN      N
# 81         120       140.0   PENNSYLVANIA      xlge          NaN      N
# 84         200       200.0       MICHIGAN       NaN          NaN      N
# 44         210       210.0     NEW JERSEY       med          NaN      N
#
# [82 rows x 10 columns]

# %%
m = df_grpby.groupby(["Package"]).agg('mean')
m
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 m = df_grpby.groupby(["Package"]).agg('mean')
#       2 m
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
